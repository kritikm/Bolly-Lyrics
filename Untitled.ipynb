# %%
suffixes = {
    1: ["ो", "े", "ू", "ु", "ी", "ि", "ा"],
    2: ["कर", "ाओ", "िए", "ाई", "ाए", "ने", "नी", "ना", "ते", "ीं", "ती", "ता", "ाँ", "ां", "ों", "ें"],
    3: ["ाकर", "ाइए", "ाईं", "ाया", "ेगी", "ेगा", "ोगी", "ोगे", "ाने", "ाना", "ाते", "ाती", "ाता", "तीं", "ाओं", "ाएं", "ुओं", "ुएं", "ुआं"],
    4: ["ाएगी", "ाएगा", "ाओगी", "ाओगे", "एंगी", "ेंगी", "एंगे", "ेंगे", "ूंगी", "ूंगा", "ातीं", "नाओं", "नाएं", "ताओं", "ताएं", "ियाँ", "ियों", "ियां"],
    5: ["ाएंगी", "ाएंगे", "ाऊंगी", "ाऊंगा", "ाइयाँ", "ाइयों", "ाइयां"],
}

def hi_stem(word):
    for L in 5, 4, 3, 2, 1:
        if len(word) > L + 1:
            for suf in suffixes[L]:
                if word.endswith(suf):
                    return word[:-L]
    return word

# if __name__ == '__main__':
#     import sys
#     if len(sys.argv) != 1:
#         sys.exit('{} takes no arguments'.format(sys.argv[0]))
#     for line in sys.stdin:
#         print(*[hi_stem(word) for word in line.split()])
# Out:
# {1: ['ो', 'े', 'ू', 'ु', 'ी', 'ि', 'ा'], 2: ['कर', 'ाओ', 'िए', 'ाई', 'ाए', 'ने', 'नी', 'ना', 'ते', 'ीं', 'ती', 'ता', 'ाँ', 'ां', 'ों', 'ें'], 3: ['ाकर', 'ाइए', 'ाईं', 'ाया', 'ेगी', 'ेगा', 'ोगी', 'ोगे', 'ाने', 'ाना', 'ाते', 'ाती', 'ाता', 'तीं', 'ाओं', 'ाएं', 'ुओं', 'ुएं', 'ुआं'], 4: ['ाएगी', 'ाएगा', 'ाओगी', 'ाओगे', 'एंगी', 'ेंगी', 'एंगे', 'ेंगे', 'ूंगी', 'ूंगा', 'ातीं', 'नाओं', 'नाएं', 'ताओं', 'ताएं', 'ियाँ', 'ियों', 'ियां'], 5: ['ाएंगी', 'ाएंगे', 'ाऊंगी', 'ाऊंगा', 'ाइयाँ', 'ाइयों', 'ाइयां']}

# %%
python hindi_stemmer.py asd asdf
# Out:
#   File "<ipython-input-7-3a7c3147ef29>", line 1
#     python hindi_stemmer.py asd asdf
#                        ^
# SyntaxError: invalid syntax

# %%
print ("मैं पुस्तकालय में किताब पढ़")
# Out:
# मैं पुस्तकालय में किताब पढ़

# %%
import os
from collections import defaultdict
import gensim
from sklearn import naive_bayes as nb
from sklearn import svm
from sklearn.model_selection import KFold
from sklearn.neural_network import MLPClassifier as mlpc
from numpy import mean

suffixes = {
    1: ["ो", "े", "ू", "ु", "ी", "ि", "ा"],
    2: ["कर", "ाओ", "िए", "ाई", "ाए", "ने", "नी", "ना", "ते", "ीं", "ती", "ता", "ाँ", "ां", "ों", "ें"],
    3: ["ाकर", "ाइए", "ाईं", "ाया", "ेगी", "ेगा", "ोगी", "ोगे", "ाने", "ाना", "ाते", "ाती", "ाता", "तीं", "ाओं", "ाएं", "ुओं", "ुएं", "ुआं"],
    4: ["ाएगी", "ाएगा", "ाओगी", "ाओगे", "एंगी", "ेंगी", "एंगे", "ेंगे", "ूंगी", "ूंगा", "ातीं", "नाओं", "नाएं", "ताओं", "ताएं", "ियाँ", "ियों", "ियां"],
    5: ["ाएंगी", "ाएंगे", "ाऊंगी", "ाऊंगा", "ाइयाँ", "ाइयों", "ाइयां"],
}

def stem(word):
    for L in 5, 4, 3, 2, 1:
        if len(word) > L + 1:
            for suf in suffixes[L]:
                if word.endswith(suf):
                    return word[:-L]
    return word


stopwords = []
project_dir = "/home/rkb/Documents/IASNLP/"	#path where the project files are
stopwords_txt = project_dir + "stopwords"

# data_dir = "cleaned/"
# classes_dir = ["pos/", "neg/"]
# classes = ["pos", "neg"]
data_dir = "four_class_data/"				#path where the dataset is
classes_dir = ["E/", "A/", "C/", "D/"]
classes = ["E", "A", "C", "D"]

target = []
songs = []

def getCorpus():
    with open(stopwords_txt) as stops:
        for stop in stops:
            stopwords.append(stop.strip())

    for dir in classes_dir:
        folder = project_dir + data_dir + dir
        for file in os.listdir(folder):
            with open(folder + file) as f:
                song = f.read().strip().split()
                song = [stem(word) for word in song if word not in stopwords]
                songs.append(song)
                target.append(classes[classes_dir.index(dir)])

getCorpus()
print (songs)
# Out:
# [['आँख', 'पन्न', 'मैं', 'लिख', 'सौ', 'दफ़', 'लफ़्ज़', 'इश्क़', 'होठ', 'बय', 'खुद', 'नाराज़', 'हूँ', 'क्य', 'बेआवाज़', 'हूँ', 'मेर', 'खामोश', 'सज़', 'दिल', 'सोच', 'फिर', 'सोच', 'किस', 'हक़', 'कहूँ', 'बत', 'मैं', 'हूँ', 'हीर', 'तेर', 'मैं', 'हूँ', 'हीर', 'तेर', 'मैं', 'हूँ', 'हीर', 'तेर', 'मैं', 'हूँ', 'हीर', 'तेर', 'तेर', 'वज़ह', 'मिल', 'जी', 'सब', 'ख्वाहिश', 'पा', 'लूं', 'तेर', 'दिल', 'जगह', 'मेर', 'कोशिश', 'मैं', 'बस', 'तेर', 'बन', 'बिन', 'तेर', 'रहूँ', 'मैं', 'मांग', 'दुआ', 'दिल', 'सोच', 'फिर', 'भी', 'पत', 'किस', 'हक़', 'कहूँ', 'बत', 'मैं', 'हूँ', 'हीर', 'तेर', 'मैं', 'हूँ', 'हीर', 'तेर', 'मैं', 'हूँ', 'हीर', 'तेर', 'मैं', 'हूँ', 'हीर', 'तेर'], ['दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'जानूं', 'मैं,', 'कैस', 'बेकरार', 'शायद', 'दिल', 'के,', 'जा', 'अब', 'तैयार', 'जानूं', 'मैं,', 'कैस', 'बेकरार', 'शायद', 'दिल', 'के,', 'जा', 'अब', 'तैयार', 'तू', 'दिल', 'ठिकाना,', 'हूँ', 'तेर', 'दीव', 'दीव', 'तेरा..', 'तुझ', 'बुल', 'मर्ज़', 'तेरी..', 'तू', 'आए', 'आए', 'दीव', 'तेरा..', 'तुझ', 'बुल', 'मर्ज़', 'तेरी,', 'तू', 'आए', 'आए', 'ऊऊ..', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'दीव', 'पूछ', 'निगाह', 'मेरी,', 'कह', 'राह', 'तेर', 'जा', 'क्य', 'जा', 'तू', 'तन्ह', 'बाह', 'मेर', 'पूछ', 'निगाह', 'मेरी,', 'कह', 'राह', 'तेर', 'जा', 'क्य', 'जा', 'तू', 'तन्ह', 'बाह', 'मेर', 'नींद', 'बिन,', 'रात', 'भी', 'गुज़ार', 'उतर', 'ना,', 'तेर', 'खुमार', 'मुश्किल', 'भुलाना,', 'हूँ', 'तेर', 'दीव', 'दीव', 'तेरा..', 'तुझ', 'बुल', 'मर्ज़', 'तेरी,', 'तू', 'आए', 'आए', 'दीव', 'तेरा..', 'तुझ', 'बुल', 'मर्ज़', 'तेरी,', 'तू', 'आए', 'आए', 'दिल', 'अरम', 'जाग', 'तेर', 'पीछ', 'भाग', 'रुक', 'तुझप', 'अब', 'जा', 'आग', 'दिल', 'अरम', 'जाग', 'तेर', 'पीछ', 'भाग', 'रुक', 'तुझप', 'अब', 'जा', 'आग', 'सूरत', 'क्य', 'आँख', 'उतार', 'मैं', 'तो,', 'भुल', 'दुनिय', 'सार', 'तुझक', 'बताना,', 'हूँ', 'तेर', 'दीव', 'दीव', 'तेरा..', 'तुझ', 'बुल', 'मर्ज़', 'तेरी,', 'तू', 'आए', 'आए', 'दीव', 'तेरा..', 'तुझ', 'बुल', 'मर्ज़', 'तेरी,', 'तू', 'आए', 'आए'], ['ज़ालिम', 'दिल्ली..', 'ज़ालिम', 'दिल्ली..', 'ज़ालिम', 'दिल्ली..', 'ज़ालिम', 'दिल्ली..', 'ज़ालिम', 'दिल्ली..', 'ज़ालिम', 'दिल्ली..', 'यो', 'yes', 'I', 'got', 'the', 'attitude', 'No,', 'not', 'like', 'being', 'rude', 'देख', 'ज़ालिम', 'दिल्ल', 'I’m', 'a', 'gangsta', 'billi', 'He', 'likes', 'my', 'style', 'my', 'flow', 'my', 'hair', 'my', 'eyes', 'When', 'I', 'walk', 'you', 'sway', 'So', 'come', 'a', 'little', 'closer', 'Put', 'your', 'arms', 'over', 'I', 'love', 'when', 'you', 'talk', 'this', 'way', 'Awesome', 'लगद', 'ऐ', 'रोमांटिक', 'मौसम', 'लगद', 'ऐ', 'बेब', 'चार्मिंग,', 'तू', 'बनज', 'डार्लिंग', 'Awesome', 'लगद', 'ऐ', 'रोमांटिक', 'मौसम', 'लगद', 'ऐ', 'बेब', 'चार्मिंग,', 'तू', 'बनज', 'डार्लिंग', 'नैन', 'नेट', 'मैं', 'हीट', 'हीट', 'जे', 'तकद', 'टा', 'दिल', 'थार', 'दे', 'नखर', 'करंट', 'मार', 'दे', 'नाच', 'बड़', 'नि', 'तेर', 'कैम', 'लगद', 'चख', 'पउग', 'तेर', 'टाइम', 'लगद', 'नाच', 'बड़', 'नि', 'तेर', 'कैम', 'लगद', 'चख', 'पउग', 'तेर', 'टाइम', 'लगद', 'हे', 'boy', 'ज़ालिम', 'दिल्ल', 'is', 'gonna', 'beat', 'to', 'the', 'drum', 'हे', 'boy', 'I’m', 'calling', 'you', 'Won’t', 'you', 'come', 'and', 'give', 'me', 'some', 'Hey', 'boy', 'won’t', 'you', 'pick', 'me', 'आ', 'तू', 'ले', 'ले', 'तू', 'मेर', 'नाम', 'ज़ालिम', 'दिल्ल', 'मेर', 'जान', 'तू', 'पी', 'ऐ', 'सिगार', 'चॉकलेट', 'वड़', 'तू', 'पढ़', 'अख़बार', 'हॉट', 'रेट', 'वड़', 'गा', 'सुन्द', 'रेहेंद', 'तू', 'पिटबुल', 'दे', 'खिटकनिय', 'डीग', 'जार', 'फिर', 'डोर', 'खुलद', 'हों', 'शिकायत', 'ऑन', 'पीछ', 'ता', 'पुथ', 'पंग', 'मुटियार', 'दे..', 'नखर', 'करंट', 'मार', 'दे', 'नच', 'बड़', 'नई', 'तेर', 'कैम', 'लगद', 'चख', 'पउग', 'तेर', 'टाइम', 'लगद', 'नच', 'बड़', 'नई', 'तेर', 'कैम', 'लगद', 'चख', 'पउग', 'तेर', 'टाइम', 'लगद', 'नच', 'बड़', 'नई', 'तेर', 'कैम', 'लगद', 'चख', 'पउग', 'तेर', 'टाइम', 'लगद'], ['तैन', 'ब्लैक', 'तैन', 'ब्लैक', 'तैन', 'ब्लैक', 'तैन', 'ब्लैक', 'सूट', 'होय', 'तेन', 'बैन', 'तहिओ', 'काल', 'सूट', 'होय', 'तेन', 'बैन', 'कुड़', 'तू', 'कुंवारी,', 'निर', 'रूप', 'दी', 'पटर', 'कुड़', 'तू', 'कुंवारी,', 'निर', 'रूप', 'दी', 'पटर', 'तेर', 'नाल', 'लौ', 'यार', 'नहिओ', 'क़त्ल', 'घात', 'तेर', 'नैन', 'नहिओ', 'क़त्ल', ' ...
